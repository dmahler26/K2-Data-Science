# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None, 'display.max_rows', 100) 

from os import path
import pickle

import sys
sys.path.append('..')
import src.functions.my_functions as my_func

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns

from sklearn.pipeline import Pipeline, FeatureUnion

from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, RandomizedSearchCV
from sklearn.metrics.scorer import make_scorer

from sklearn.metrics import f1_score, recall_score, precision_score, fbeta_score

from sklearn.svm import LinearSVC, SVC

from sklearn.feature_selection import SelectFromModel, SelectKBest, SelectPercentile, RFE, RFECV, f_classif

from sklearn.decomposition import PCA

# %%
from imp import reload
reload(my_func)
# Out:
# <module 'src.functions.my_functions' from '..\\src\\functions\\my_functions.py'>

# %% [markdown]
# ### Import

# %%
data = {}

ds = ['train', 'train_target', 'test', 'test_target']
d = ['..', 'data', 'processed']

for s in ds:    
    fn = 'loan_'+s+'.p'
    fp = path.join(*d, fn)

    with open(fp, 'rb') as file:
        data[s] = pickle.load(file)

# %%
data['train'].shape, data['train_target'].shape
# Out:
# ((152218, 47), (152218, 2))

# %%
data['test'].shape, data['test_target'].shape
# Out:
# ((38055, 47), (38055, 2))

# %% [markdown]
# ### Data Prep

# %%
# Columns identified thus far as best for classification (during data prep, select K best)
num_attr = ['funded_amnt_q10', 'int_rate_delta', 'annual_inc_q10', 'dti', 'delinq_2yrs', 'inq_last_6mths',
            'open_acc', 'revol_bal_log', 'revol_util', 'total_acc', 'collections_12_mths_ex_med',
            'acc_now_delinq', 'rev_lim_sqrt', 'tot_cur_bal', 'tot_coll_amt', 'subgrade_p_value',
            'lti', 'rbti', 'tbti', 'cr_line_td_log', 'emp_length_val']

bin_attr = ['had_delinq', 'had_major_derog', 'had_record', 'verified', 'term_bin']

cat_attr = ['purpose', 'home_ownership']

# %%
num_prep = Pipeline([('custom', my_func.CustomNumAttributes()), # Create custom num attr
                     ('select', my_func.DataFrame_Selector(num_attr)), # Select num columns
                     ('sc', StandardScaler())]) # Standardize data

bin_prep = Pipeline([('custom', my_func.CustomBinAttributes()), # Create custom bin attr
                     ('select', my_func.DataFrame_Selector(bin_attr))]) # Select binary columns

cat_prep = Pipeline([('encode', my_func.DataFrame_DummyEncoder(cat_attr))]) # Select & encode categrocial columns

feature_prep = FeatureUnion([('num', num_prep),
                             ('bin', bin_prep),
                             ('cat', cat_prep)])

# %%
X_train_full = feature_prep.fit_transform(data['train'])

# %%
X_test = feature_prep.transform(data['test'])

# %%
X_train_full.shape, X_test.shape
# Out:
# ((152218, 44), (38055, 44))

# %%
y_train_full = data['train_target']['default']
y_test = data['test_target']['default']

y_train_full.shape, y_test.shape
# Out:
# ((152218,), (38055,))

# %%
def get_feature_prep_columns(feature_union):
    num_cols = feature_union.transformer_list[0][1].named_steps['select'].get_feature_names()
    bin_cols = feature_union.transformer_list[1][1].named_steps['select'].get_feature_names()
    cat_cols = feature_union.transformer_list[2][1].named_steps['encode'].get_feature_names()
    cols = num_cols + bin_cols + cat_cols
    return cols

# %%
feature_names = get_feature_prep_columns(feature_prep)
len(feature_names)
# Out:
# 44

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# %% [markdown]
# ### Scoring

# %% [markdown]
# Continuing the approach used with our logistic regression analysis, we will be using F2 score as a means of prioritizing recall over precision:

# %%
f2_score = make_scorer(fbeta_score, beta=2)

# %% [markdown]
# ### Linear SVC

# %% [markdown]
# ##### Basic Model

# %%
lsvc_basic = LinearSVC(class_weight='balanced')

# %%
my_func.run_time(reset=True)
lsvc_basic.fit(X_train, y_train)
my_func.run_time()
# Out:
# Time: 24.30s

# %%
my_func.classifier_summary(y_train, lsvc_basic.predict(X_train));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               64189               34125
# Actual Positive                8168               15292
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.533726
# Recall           0.651833
# Precision (pos)  0.309448
# Precision (neg)  0.887115
# Specificity      0.652898

# %%
my_func.classifier_summary(y_val, lsvc_basic.predict(X_val));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               16132                8498
# Actual Positive                2026                3788
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.532891
# Recall           0.651531
# Precision (pos)  0.308318
# Precision (neg)  0.888424
# Specificity      0.654974

# %% [markdown]
# ##### Learning Curve

# %%
my_func.plot_learning_curve(lsvc_basic, X_train, y_train, scoring=['f2', 'recall', 'precision'], train_sizes=np.arange(0.1,1.1,0.1), n_jobs=4)

# %% [markdown]
# Our scores seem to stabalize around 40,000 samples. Given the extreme impact of sample size on the computational complexity for SVC, reducing to 40,000 samples may provide a more practical approach without much impact on model performance:

# %%
rand_ind = np.random.choice(np.arange(0, X_train.shape[0], 1), size=40000, replace=False)

X_train_s = X_train[rand_ind]
y_train_s = y_train.iloc[rand_ind]

# %%
my_func.run_time(reset=True)
lsvc_basic.fit(X_train_s, y_train_s)
my_func.run_time()
# Out:
# Time: 6.75s

# %%
my_func.print_cvs(cross_val_score(lsvc_basic, X_train_s, y_train_s, cv=3, scoring=f2_score), 'f2')
# Out:
# Mean f2 score = 0.526 (+/- 0.009)

# %%
my_func.classifier_summary(y_train_s, lsvc_basic.predict(X_train_s));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               21183               11244
# Actual Positive                2668                4905
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.528089
# Recall           0.647696
# Precision (pos)  0.303734
# Precision (neg)  0.888139
# Specificity      0.653252

# %%
my_func.classifier_summary(y_val, lsvc_basic.predict(X_val));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               16145                8485
# Actual Positive                2041                3773
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.531199
# Recall           0.648951
# Precision (pos)  0.307799
# Precision (neg)  0.887771
# Specificity      0.655501

# %% [markdown]
# Our reduced sample model performs nearly identically to the full training set, with scores only suffering on the magnitude of 0.01 and litte signs of over-/under-fitting.

# %% [markdown]
# ##### Feature Selection

# %% [markdown]
# Given the significantly higher computation times for even LinearSVC as a result of the large number of training instances, perhaps some improvements can also be made to both fit times and model performance via feature selection. Given our learning curve results above, we should be able to perform optimizations using 40,000 samples without a signficiant cost to accuracy.

# %%
RFE_scores = my_func.plot_RFE(estimator=LinearSVC(class_weight='balanced'), X=X_train_s, y=y_train_s, f_score=True, beta=2, n_jobs=4)

# %% [markdown]
# We seem to be encountering a similar issue as our Logistic Regression RFE process, in which only 1 feature is being selected. For the same reasons of one feature being too biased and inflexible, we will seek out the next highest score:

# %%
# Index = n_features since we start at [1:]
np.argmax(RFE_scores['F2'][1:])
# Out:
# 31

# %%
lsvc_rfe = Pipeline([('rfe', RFE(estimator=LinearSVC(class_weight='balanced'), n_features_to_select=31)),
                     ('estimator', LinearSVC(class_weight='balanced'))])

lsvc_rfe.fit(X_train_s, y_train_s);

# %%
lsvc_rfe_cvs = cross_val_score(lsvc_rfe, X_train_s, y_train_s, cv=3, scoring=f2_score)
my_func.print_cvs(lsvc_rfe_cvs)
# Out:
# Mean CV score = 0.525 (+/- 0.010)

# %%
my_func.classifier_summary(y_train_s, lsvc_rfe.predict(X_train_s));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               21121               11306
# Actual Positive                2655                4918
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.528635
# Recall           0.649412
# Precision (pos)  0.303131
# Precision (neg)  0.888333
# Specificity      0.651340

# %%
my_func.classifier_summary(y_val, lsvc_rfe.predict(X_val));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               16103                8527
# Actual Positive                2039                3775
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.530823
# Recall           0.649295
# Precision (pos)  0.306861
# Precision (neg)  0.887609
# Specificity      0.653796

# %% [markdown]
# Our model performs almost identically to previous versions, whilst reducing the the number of features to 31. Running through this via pipeline takens longer than our default fit due to having to run through both the RFE and LinearSVC. However, for the purposes of subsequent tuning if we extract the RFE process to obtain a new transformed training set we should see at least some improvements to computation times.

# %%
rfe = RFE(estimator=LinearSVC(class_weight='balanced'), n_features_to_select=31)
rfe.fit(X_train_s, y_train_s)
# Out:
# RFE(estimator=LinearSVC(C=1.0, class_weight='balanced', dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#   n_features_to_select=31, step=1, verbose=0)

# %%
X_train_s_rfe = rfe.transform(X_train_s)

# %% [markdown]
# ##### Parameter Tuning

# %% [markdown]
# First, we will take a look at how variations to C alone impact performance (with default L2 penalty and squared hinge loss):

# %%
scoring={'F2': f2_score,
         'recall':'recall',
         'precision':'precision'}

param_grid = {'C': np.logspace(-9,3,13)}
              

lsvc_C_gs = GridSearchCV(estimator=LinearSVC(class_weight='balanced', tol=0.001), # Slightly reduce tol to improve comp time
                  param_grid = param_grid,
                  scoring=scoring,
                  cv=3,
                  refit=False,
                  n_jobs=4)

my_func.run_time(reset=True)
lsvc_C_gs.fit(X_train_s_rfe, y_train_s)
my_func.run_time()
# Out:
# Time: 22.64s

# %%
my_func.plot_gs_param(lsvc_C_gs, set_xscale='log')

# %% [markdown]
# We can see that lower C values produce favorable recall and F2 scores. As for the performance of regularization across L1 and L2 penalty:

# %%
scoring={'F2': f2_score,
         'recall':'recall',
         'precision':'precision'}

param_grid = {'C': np.logspace(-9,0,10),
              'penalty': ['l1', 'l2']}
              

lsvc_pen_gs = GridSearchCV(estimator=LinearSVC(class_weight='balanced', dual=False, tol=0.001), # Slightly reduce tol to improve comp time
                  param_grid = param_grid,
                  scoring=scoring,
                  cv=3,
                  refit=False,
                  n_jobs=4)

my_func.run_time(reset=True)
lsvc_pen_gs.fit(X_train_s_rfe, y_train_s)
my_func.run_time()
# Out:
# Time: 8.53s

# %%
my_func.plot_gs_param_dual(lsvc_pen_gs, cbar=True, scoring='F2', power_scale=10, swap_axes=True, figsize=(12,5))

# %% [markdown]
# With this basic comparison, it would seem that L2 penalty produces better results than L1. We will proceed with a full gridsearch of both penalties with various loss combinations as well to ensure we are not missing any edge cases which perform best:

# %%
scoring={'F2': f2_score,
         'recall':'recall',
         'precision':'precision'}

param_grid = [{'C': np.logspace(-9,0,10),
               'loss': ['squared_hinge'],
               'dual': [False],
               'penalty': ['l1', 'l2']},
              {'C': np.logspace(-9,0,10),
               'loss': ['hinge'],
               'dual': [True],
               'penalty': ['l2']}]
              

lsvc_gs = GridSearchCV(estimator=LinearSVC(class_weight='balanced', tol=0.001), # Slightly reduce tol to improve comp time
                  param_grid = param_grid,
                  scoring=scoring,
                  cv=3,
                  refit=False,
                  n_jobs=4)

my_func.run_time(reset=True)
lsvc_gs.fit(X_train_s_rfe, y_train_s)
my_func.run_time()
# Out:
# Time: 10.02s

# %%
my_func.gs_score_summary(lsvc_gs)
# Out:
# --------------------
# Best F2:
# Params: {'C': 9.9999999999999995e-08, 'dual': False, 'loss': 'squared_hinge', 'penalty': 'l2'}
# F2 = 0.5576169613083233
# Recall = 0.7545227382396322
# Precision = 0.2728258047592347
# --------------------
# Best Recall:
# Params: {'C': 1.0000000000000001e-09, 'dual': False, 'loss': 'squared_hinge', 'penalty': 'l2'}
# F2 = 0.5575061543539285
# Recall = 0.7553149842541307
# Precision = 0.2722808360084937
# --------------------
# Best Precision:
# Params: {'C': 0.001, 'dual': False, 'loss': 'squared_hinge', 'penalty': 'l2'}
# F2 = 0.5292348669507614
# Recall = 0.6513951324786995
# Precision = 0.3024508042244662
# --------------------

# %% [markdown]
# With our high levels of regularization, it should be feasible to return to using our full training set for scoring:

# %%
X_train_rfe = rfe.transform(X_train)
X_val_rfe = rfe.transform(X_val)

# %%
lsvc_best = LinearSVC(class_weight='balanced', loss='squared_hinge', dual=False, penalty='l2', C=1e-7)

my_func.run_time(reset=True)
lsvc_best.fit(X_train_rfe, y_train)
my_func.run_time()
# Out:
# Time: 205ms

# %%
my_func.classifier_summary(y_train, lsvc_best.predict(X_train_rfe));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               52826               45488
# Actual Positive                5867               17593
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.560569
# Recall           0.749915
# Precision (pos)  0.278895
# Precision (neg)  0.900039
# Specificity      0.537319

# %%
my_func.classifier_summary(y_val, lsvc_best.predict(X_val_rfe));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               13258               11372
# Actual Positive                1471                4343
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.557209
# Recall           0.746990
# Precision (pos)  0.276360
# Precision (neg)  0.900129
# Specificity      0.538287

# %% [markdown]
# ##### PCA

# %% [markdown]
# Although we already performed feature selection, perhaps PCA will perform better. We will repeat grid search parameter tuning using the sample training set (for performance reasons), this time adding different levels of PCA components:

# %%
rand_ind = np.random.choice(np.arange(0, X_train.shape[0], 1), size=40000, replace=False)

X_train_s = X_train[rand_ind]
y_train_s = y_train.iloc[rand_ind]

# %%
lr_pca = Pipeline([('pca', PCA()),
                     ('estimator', LinearSVC(tol=0.001))])

scoring = {'F2': f2_score,
           'recall': 'recall',
           'precision': 'precision',
           'specificity': make_scorer(my_func.binary_specificity)}

param_grid = [{'estimator__C': np.logspace(-9,0,10),
              'estimator__class_weight': ['balanced'],
              'estimator__penalty': ['l1', 'l2'],
              'estimator__loss': ['squared_hinge'],
              'estimator__dual': [False],
              'pca__n_components': [None, 0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 0.99, 0.999]},
             {'estimator__C': np.logspace(-9,0,10),
              'estimator__class_weight': ['balanced'],
              'estimator__dual': [True],
              'estimator__penalty': ['l2'],
              'estimator__loss': ['hinge'],
              'pca__n_components': [None, 0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 0.99, 0.999]}]

lr_pca_gs = GridSearchCV(estimator=lr_pca,
                  param_grid = param_grid,
                  scoring=scoring,
                  cv=3,
                  refit=False,
                  n_jobs=4)

my_func.run_time(reset=True)
lr_pca_gs.fit(X_train_s_r, y_train_s);
my_func.run_time()
# Out:
# Time: 2min 25s

# %%
my_func.gs_score_summary(lr_pca_gs)
# Out:
# --------------------
# Best F2:
# Params: {'estimator__C': 9.9999999999999995e-07, 'estimator__class_weight': 'balanced', 'estimator__dual': False, 'estimator__loss': 'squared_hinge', 'estimator__penalty': 'l2', 'pca__n_components': 0.95}
# F2 = 0.5482572884825149
# Recall = 0.7236221751968503
# Precision = 0.2784130443545622
# Specificity = 0.5585855926222503
# --------------------
# Best Recall:
# Params: {'estimator__C': 1e-08, 'estimator__class_weight': 'balanced', 'estimator__dual': False, 'estimator__loss': 'squared_hinge', 'estimator__penalty': 'l2', 'pca__n_components': 0.95}
# F2 = 0.5481408214925722
# Recall = 0.7261156200787402
# Precision = 0.2768007461205925
# Specificity = 0.5534898550555203
# --------------------
# Best Precision:
# Params: {'estimator__C': 1.0, 'estimator__class_weight': 'balanced', 'estimator__dual': False, 'estimator__loss': 'squared_hinge', 'estimator__penalty': 'l2', 'pca__n_components': 0.999}
# F2 = 0.5315660269855523
# Recall = 0.6502624507874015
# Precision = 0.30725038847266906
# Specificity = 0.6549413552906024
# --------------------
# Best Specificity:
# Params: {'estimator__C': 1.0000000000000001e-09, 'estimator__class_weight': 'balanced', 'estimator__dual': False, 'estimator__loss': 'squared_hinge', 'estimator__penalty': 'l1', 'pca__n_components': None}
# F2 = 0.0
# Recall = 0.0
# Precision = 0.0
# Specificity = 1.0
# --------------------

# %%
lr_pca_best = Pipeline([('pca', PCA(n_components=0.95)),
                     ('estimator', LinearSVC(class_weight='balanced', C=1e-6, loss='squared_hinge', penalty='l2', dual=False))])

lr_pca_best.fit(X_train, y_train);

# %%
lr_pca_best.named_steps['pca'].n_components_
# Out:
# 21

# %%
lr_pca_cvs = cross_val_score(lr_pca_best, X_train, y_train, scoring=f2_score, n_jobs=4)

my_func.print_cvs(lr_pca_cvs, 'f2')
# Out:
# Mean f2 score = 0.551 (+/- 0.002)

# %%
my_func.classifier_summary(y_train, pca_best.predict(X_train));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               56580               41734
# Actual Positive                6670               16790
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.550983
# Recall           0.715686
# Precision (pos)  0.286891
# Precision (neg)  0.894545
# Specificity      0.575503

# %%
my_func.classifier_summary(y_val, pca_best.predict(X_val));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               14185               10445
# Actual Positive                1658                4156
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.548908
# Recall           0.714826
# Precision (pos)  0.284638
# Precision (neg)  0.895348
# Specificity      0.575924

# %% [markdown]
# PCA alone is not able to exceed the performance of our RFE approach. We will see if adding PCA on top of our original RFE feature selection provides any additional benefits:

# %%
lr_rfe_pca = Pipeline([('pca', PCA()),
                     ('estimator', LinearSVC(tol=0.001))])

scoring = {'F2': f2_score,
           'recall': 'recall',
           'precision': 'precision',
           'specificity': make_scorer(my_func.binary_specificity)}

param_grid = [{'estimator__C': np.logspace(-9,0,10),
              'estimator__class_weight': ['balanced'],
              'estimator__penalty': ['l1', 'l2'],
              'estimator__loss': ['squared_hinge'],
              'estimator__dual': [False],
              'pca__n_components': [None, 0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 0.99, 0.999]},
             {'estimator__C': np.logspace(-9,0,10),
              'estimator__class_weight': ['balanced'],
              'estimator__dual': [True],
              'estimator__penalty': ['l2'],
              'estimator__loss': ['hinge'],
              'pca__n_components': [None, 0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 0.99, 0.999]}]

lr_rfe_pca_gs = GridSearchCV(estimator=lr_rfe_pca,
                  param_grid = param_grid,
                  scoring=scoring,
                  cv=3,
                  refit=False,
                  n_jobs=4)

my_func.run_time(reset=True)
lr_rfe_pca_gs.fit(X_train_s_rfe, y_train_s);
my_func.run_time()
# Out:
# Time: 2min 18s

# %%
my_func.gs_score_summary(lr_rfe_pca_gs)
# Out:
# --------------------
# Best F2:
# Params: {'estimator__C': 1e-08, 'estimator__class_weight': 'balanced', 'estimator__dual': False, 'estimator__loss': 'squared_hinge', 'estimator__penalty': 'l2', 'pca__n_components': None}
# F2 = 0.5524182649937198
# Recall = 0.729658937007874
# Precision = 0.28020377818647724
# Specificity = 0.5588635446991331
# --------------------
# Best Recall:
# Params: {'estimator__C': 1.0000000000000001e-09, 'estimator__class_weight': 'balanced', 'estimator__dual': False, 'estimator__loss': 'squared_hinge', 'estimator__penalty': 'l2', 'pca__n_components': 0.5}
# F2 = 0.5498082547608021
# Recall = 0.7299213779527559
# Precision = 0.27671583356949975
# Specificity = 0.5509883098014156
# --------------------
# Best Precision:
# Params: {'estimator__C': 0.01, 'estimator__class_weight': 'balanced', 'estimator__dual': False, 'estimator__loss': 'squared_hinge', 'estimator__penalty': 'l2', 'pca__n_components': None}
# F2 = 0.5307330037425086
# Recall = 0.6496062992125984
# Precision = 0.30644750907536955
# Specificity = 0.65398397564432
# --------------------
# Best Specificity:
# Params: {'estimator__C': 1.0000000000000001e-09, 'estimator__class_weight': 'balanced', 'estimator__dual': False, 'estimator__loss': 'squared_hinge', 'estimator__penalty': 'l1', 'pca__n_components': None}
# F2 = 0.0
# Recall = 0.0
# Precision = 0.0
# Specificity = 1.0
# --------------------

# %% [markdown]
# Our best F2 score requires utilizing all components, so PCA is unable to provide any additional improvement over RFE.

# %% [markdown]
# ##### PR Curve

# %%
precisions, recalls, thresholds = my_func.plot_pr_curve(lsvc_best, X_train, y_train, f_score=True, beta=2, label='Logistic Regression')
# Out:
# ..\src\functions\my_functions.py:337: RuntimeWarning: invalid value encountered in true_divide
#   f_scores = (1 + beta**2) * (precisions * recalls) / ((beta**2 * precisions) + recalls)

# %% [markdown]
# Changing the decision threshold to maximize F2 can lead to a recall score of approx. 0.9, but it reduces our precision below our desired minimum of 0.25. Perhaps a slightly more conservative value, i.e. -0.002, will yield a better balance:

# %%
# Filter results based off new threshold
t = -0.002

y_train_pred_t = lsvc_best.decision_function(X_train_rfe) > t
y_val_pred_t = lsvc_best.decision_function(X_val_rfe) > t

# %%
my_func.classifier_summary(y_train, y_train_pred_t);
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               48742               49572
# Actual Positive                5138               18322
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.566424
# Recall           0.780989
# Precision (pos)  0.269862
# Precision (neg)  0.904640
# Specificity      0.495779

# %%
my_func.classifier_summary(y_val, y_val_pred_t);
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               12265               12365
# Actual Positive                1281                4533
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.564452
# Recall           0.779670
# Precision (pos)  0.268257
# Precision (neg)  0.905433
# Specificity      0.497970

# %% [markdown]
# Whilst we have managed to increase recall to 0.77 via this new threshold, specificty has decreased below 0.5 meaning we are losing over half of our healthy loans as false positives. From a business standpoint this is unlikely to be an acceptable loss.

# %% [markdown]
# ### Polynomial SVC

# %% [markdown]
# ##### Learning Curve

# %% [markdown]
# As seen during the MVP analysis, computing this model takes an extremely long time due to the number of training instances. Consequently, we will see how the model performs in the 10-90% sample size range to see if it is feasible to work with a smaller training sample:

# %%
my_func.plot_learning_curve(SVC(class_weight='balanced', kernel='poly', degree=2), X_train, y_train, scoring=['f2', 'recall', 'precision'], train_sizes=np.arange(0.1,1.0,0.2), n_jobs=4)

# %% [markdown]
# Whilst there is still room for improvement between the train and validation scores, i

# %% [markdown]
# ##### Basic Model

# %%
psvc_basic = SVC(kernel='poly', degree=2, class_weight='balanced')

my_func.run_time(reset=True)
psvc_basic.fit(X_train, y_train)
my_func.run_time()
# Out:
# Time: 26min 10s

# %%
my_func.classifier_summary(y_train, psvc_basic.predict(X_train_norm));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               81840               16474
# Actual Positive               14422                9038
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.378628
# Recall           0.385251
# Precision (pos)  0.354265
# Precision (neg)  0.850180
# Specificity      0.832435

# %%
my_func.classifier_summary(y_val, psvc_basic.predict(X_val_norm));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               20614                4016
# Actual Positive                3564                2250
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.381072
# Recall           0.386997
# Precision (pos)  0.359081
# Precision (neg)  0.852593
# Specificity      0.836947

# %% [markdown]
# ##### Parameter Tuning

# %%
rand_ind = np.random.choice(np.arange(0, X_train.shape[0], 1), size=10000, replace=False)

X_train_s = X_train[rand_ind]
y_train_s = y_train.iloc[rand_ind]

# %%
psvc_pipe = Pipeline([('norm', Normalizer()),
                      ('estimator', SVC(class_weight='balanced', kernel='poly', C=.10, gamma=1, degree=2, cache_size=1000))])

my_func.run_time(reset=True)
psvc_pipe.fit(X_train_s, y_train_s)
my_func.run_time()
# Out:
# Time: 30.08s

# %%
scoring={'F2': f2_score,
         'recall':'recall',
         'precision':'precision'}

param_grid = {'C': np.logspace(-6,3,10)}
              

psvc_d2_C_gs = GridSearchCV(estimator=SVC(kernel='poly', degree=2, class_weight='balanced', tol=0.01), # Slightly reduce tol to improve comp time
                          param_grid = param_grid,
                          scoring=scoring,
                          cv=3,
                          refit=False,
                          n_jobs=4,
                          verbose=1)

my_func.run_time(reset=True)
psvc_d2_C_gs.fit(X_train_s, y_train_s)
my_func.run_time()
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Time: 67min 11s
# [Parallel(n_jobs=4)]: Done  30 out of  30 | elapsed: 67.2min finished

# %%
my_func.plot_gs_param(psvc_d2_C_gs, set_xscale='log', figsize=(12,7))

# %% [markdown]
# We clearly start seeing volatile behavior below C = 0.001, so the ultimate gridsearch should probably limit itself to a C range of 0.001 to 1000. The variations seen could also be a symptom of the smaller sample size, but from a computational standpoint it would be expensive to increase it further.

# %%
rand_ind = np.random.choice(np.arange(0, X_train.shape[0], 1), size=2000, replace=False)

X_train_s = X_train[rand_ind]
y_train_s = y_train.iloc[rand_ind]

# %%
np.logspace(-6,3,10)
# Out:
# array([  1.00000000e-06,   1.00000000e-05,   1.00000000e-04,
#          1.00000000e-03,   1.00000000e-02,   1.00000000e-01,
#          1.00000000e+00,   1.00000000e+01,   1.00000000e+02,
#          1.00000000e+03])

# %%
psvc_basic = SVC(class_weight='balanced', kernel='poly', degree=2, gamma=1, cache_size=1000)

my_func.run_time(reset=True)
psvc_basic.fit(X_train_s, y_train_s)
my_func.run_time()
# Out:
# Time: 9.26s

# %%
np.logspace(-6,2,9)

# %%
scoring={'F2': f2_score,
         'recall':'recall',
         'precision':'precision'}

param_grid = {'gamma': np.logspace(-6,3,10)}
              

psvc_d2_g_gs = GridSearchCV(estimator=SVC(kernel='poly', class_weight='balanced', degree=2, tol=0.01), # Slightly reduce tol to improve comp time
                          param_grid = param_grid,
                          scoring=scoring,
                          cv=3,
                          refit=False,
                          n_jobs=4,
                          verbose=3)

my_func.run_time(reset=True)
psvc_d2_g_gs.fit(X_train_s, y_train_s)
my_func.run_time()
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Time: 5.51s
# [Parallel(n_jobs=4)]: Done  30 out of  30 | elapsed:    5.2s finished

# %%
my_func.plot_gs_param(psvc_d2_g_gs, set_xscale='log', figsize=(12,7))

# %%
scoring={'F2': f2_score,
         'recall':'recall',
         'precision':'precision',
         'specificity': make_scorer(my_func.binary_specificity)}

param_grid = {'C': np.logspace(-4,2,7),
              'gamma': np.logspace(-4,0,5),
              'degree': [2],
              'class_weight': ['balanced']}
              

psvc_d2_gs = GridSearchCV(estimator=SVC(kernel='poly', tol=0.01), # Slightly reduce tol to improve comp time
                          param_grid = param_grid,
                          scoring=scoring,
                          cv=3,
                          refit=False,
                          n_jobs=1,
                          verbose=10)

my_func.run_time(reset=True)
psvc_d2_gs.fit(X_train_s, y_train_s)
my_func.run_time()
# Out:
# Fitting 3 folds for each of 35 candidates, totalling 105 fits
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.0001 .........
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.0001, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  46.4s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.0001 .........
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.6min remaining:    0.0s
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.0001, F2=0.5446927374301676, recall=1.0, precision=0.19306930693069307, specificity=0.0, total=  47.7s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.0001 .........
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  3.2min remaining:    0.0s
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  48.6s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.001 ..........
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  4.8min remaining:    0.0s
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.001, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  50.3s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.001 ..........
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  6.4min remaining:    0.0s
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.001, F2=0.5446927374301676, recall=1.0, precision=0.19306930693069307, specificity=0.0, total=  50.6s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.001 ..........
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  8.1min remaining:    0.0s
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  51.5s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.01 ...........
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  9.8min remaining:    0.0s
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.01, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  51.0s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.01 ...........
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 11.5min remaining:    0.0s
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.01, F2=0.5446927374301676, recall=1.0, precision=0.19306930693069307, specificity=0.0, total=  50.7s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.01 ...........
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 13.1min remaining:    0.0s
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.01, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  44.6s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.1 ............
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 14.6min remaining:    0.0s
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.1, F2=0.5447388470329299, recall=0.9992236024844721, precision=0.1932142320972827, specificity=0.0011152416356877324, total=  50.2s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.1 ............
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.1, F2=0.0009678668215253582, recall=0.000777000777000777, precision=0.05555555555555555, specificity=0.9968395612567392, total=  51.6s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=0.1 ............
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=0.1, F2=0.001940617116242965, recall=0.001554001554001554, precision=0.4, specificity=0.9994422755158952, total=  51.2s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=1.0 ............
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=1.0, F2=0.5236287472182223, recall=0.6211180124223602, precision=0.32167269802975473, specificity=0.6864312267657993, total=  44.9s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=1.0 ............
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=1.0, F2=0.4769936580758332, recall=0.5493395493395493, precision=0.312417145382236, specificity=0.71072690091095, total=  37.3s
# [CV] C=0.0001, class_weight=balanced, degree=2, gamma=1.0 ............
# [CV]  C=0.0001, class_weight=balanced, degree=2, gamma=1.0, F2=0.5266648978508888, recall=0.616938616938617, precision=0.3322175732217573, specificity=0.7032905744562187, total=  40.0s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.0001 ..........
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.0001, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  49.1s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.0001 ..........
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.0001, F2=0.5446927374301676, recall=1.0, precision=0.19306930693069307, specificity=0.0, total=  53.2s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.0001 ..........
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.0001, F2=0.5446927374301676, recall=1.0, precision=0.19306930693069307, specificity=0.0, total=  52.8s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.001 ...........
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.001, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  53.4s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.001 ...........
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.001, F2=0.5446927374301676, recall=1.0, precision=0.19306930693069307, specificity=0.0, total=  52.5s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.001 ...........
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.001, F2=0.5446927374301676, recall=1.0, precision=0.19306930693069307, specificity=0.0, total=  50.7s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.01 ............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.01, F2=0.5445083770519547, recall=0.9992236024844721, precision=0.19306930693069307, specificity=0.0001858736059479554, total=  47.2s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.01 ............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.01, F2=0.5446927374301676, recall=1.0, precision=0.19306930693069307, specificity=0.0, total=  49.6s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.01 ............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.01, F2=0.001939111886755866, recall=0.001554001554001554, precision=0.2222222222222222, specificity=0.998698642870422, total=  50.6s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.1 .............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.1, F2=0.42963514519731943, recall=0.44798136645962733, precision=0.3691618682021753, specificity=0.816728624535316, total=  51.8s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.1 .............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.1, F2=0.3289266603714196, recall=0.3247863247863248, precision=0.3466003316749585, specificity=0.8535043688417921, total=  50.6s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=0.1 .............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=0.1, F2=0.4018058690744921, recall=0.4149184149184149, precision=0.35671342685370744, specificity=0.8209704406023425, total=  50.7s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=1.0 .............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=1.0, F2=0.5379984951091046, recall=0.6661490683229814, precision=0.3040396881644224, specificity=0.6349442379182156, total=  40.8s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=1.0 .............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=1.0, F2=0.5175731144176501, recall=0.627039627039627, precision=0.3047583081570997, specificity=0.657743074920989, total=  41.0s
# [CV] C=0.001, class_weight=balanced, degree=2, gamma=1.0 .............
# [CV]  C=0.001, class_weight=balanced, degree=2, gamma=1.0, F2=0.5498238550578761, recall=0.679098679098679, precision=0.31214285714285717, specificity=0.6419408812046848, total=  27.8s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.0001 ...........
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.0001, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  31.3s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.0001 ...........
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  31.3s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.0001 ...........
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  31.0s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.001 ............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.001, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  30.9s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.001 ............
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  31.4s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.001 ............
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  31.3s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.01 .............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.01, F2=0.5447388470329299, recall=0.9992236024844721, precision=0.1932142320972827, specificity=0.0011152416356877324, total=  31.2s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.01 .............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.01, F2=0.0009678668215253582, recall=0.000777000777000777, precision=0.05555555555555555, specificity=0.9968395612567392, total=  30.9s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.01 .............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.01, F2=0.001940617116242965, recall=0.001554001554001554, precision=0.4, specificity=0.9994422755158952, total=  30.9s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.1 ..............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.1, F2=0.5236973029588897, recall=0.6211180124223602, precision=0.32180209171359614, specificity=0.6866171003717472, total=  26.7s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.1 ..............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.1, F2=0.4769293038316244, recall=0.5493395493395493, precision=0.3122791519434629, specificity=0.7105409927495817, total=  26.1s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=0.1 ..............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=0.1, F2=0.52673477510946, recall=0.616938616938617, precision=0.33235663457513603, specificity=0.7034764826175869, total=  26.6s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=1.0 ..............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=1.0, F2=0.5345558882235529, recall=0.6653726708074534, precision=0.299231843575419, specificity=0.6269516728624536, total=  26.8s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=1.0 ..............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=1.0, F2=0.5154574132492113, recall=0.6348096348096348, precision=0.29420237666546634, specificity=0.6356200037181632, total=  25.8s
# [CV] C=0.01, class_weight=balanced, degree=2, gamma=1.0 ..............
# [CV]  C=0.01, class_weight=balanced, degree=2, gamma=1.0, F2=0.5429104477611941, recall=0.6783216783216783, precision=0.30186721991701243, specificity=0.6246514221974344, total=  27.1s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.0001 ............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.0001, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  31.2s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.0001 ............
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  31.0s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.0001 ............
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  31.1s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.001 .............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.001, F2=0.5445083770519547, recall=0.9992236024844721, precision=0.19306930693069307, specificity=0.0001858736059479554, total=  32.8s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.001 .............
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  31.9s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.001 .............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.001, F2=0.0, recall=0.0, precision=0.0, specificity=0.9998140918386317, total=  33.0s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.01 ..............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.01, F2=0.42963514519731943, recall=0.44798136645962733, precision=0.3691618682021753, specificity=0.816728624535316, total=  32.7s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.01 ..............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.01, F2=0.3289266603714196, recall=0.3247863247863248, precision=0.3466003316749585, specificity=0.8535043688417921, total=  32.7s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.01 ..............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.01, F2=0.4018058690744921, recall=0.4149184149184149, precision=0.35671342685370744, specificity=0.8209704406023425, total=  33.3s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.1 ...............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.1, F2=0.5381334671349725, recall=0.6661490683229814, precision=0.30425531914893617, specificity=0.6353159851301116, total=  25.9s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.1 ...............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.1, F2=0.5175067333589842, recall=0.627039627039627, precision=0.304643261608154, specificity=0.6575571667596207, total=  25.5s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=0.1 ...............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=0.1, F2=0.5497546861240407, recall=0.679098679098679, precision=0.3120314173509461, specificity=0.6417549730433166, total=  26.2s
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=1.0 ...............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=1.0, F2=0.518957047487089, recall=0.639751552795031, precision=0.2956584140653032, specificity=0.6351301115241635, total= 1.2min
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=1.0 ...............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=1.0, F2=0.501585288522511, recall=0.6146076146076146, precision=0.289002557544757, specificity=0.6382227179773192, total= 1.2min
# [CV] C=0.1, class_weight=balanced, degree=2, gamma=1.0 ...............
# [CV]  C=0.1, class_weight=balanced, degree=2, gamma=1.0, F2=0.5328996747560671, recall=0.662004662004662, precision=0.29936753338018274, specificity=0.6292991262316415, total= 1.2min
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.0001 ............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.0001, F2=0.544839255499154, recall=1.0, precision=0.1931613677264547, specificity=0.0, total=  32.4s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.0001 ............
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  33.2s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.0001 ............
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  33.3s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.001 .............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.001, F2=0.5447388470329299, recall=0.9992236024844721, precision=0.1932142320972827, specificity=0.0011152416356877324, total=  33.5s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.001 .............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.001, F2=0.0009678668215253582, recall=0.000777000777000777, precision=0.05555555555555555, specificity=0.9968395612567392, total=  33.4s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.001 .............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.001, F2=0.001940617116242965, recall=0.001554001554001554, precision=0.4, specificity=0.9994422755158952, total=  32.3s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.01 ..............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.01, F2=0.5231111693073196, recall=0.6203416149068323, precision=0.3215291750503018, specificity=0.6866171003717472, total=  26.7s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.01 ..............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.01, F2=0.4769936580758332, recall=0.5493395493395493, precision=0.312417145382236, specificity=0.71072690091095, total=  26.1s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.01 ..............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.01, F2=0.526525198938992, recall=0.616938616938617, precision=0.3319397993311037, specificity=0.702918758133482, total=  26.5s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.1 ...............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.1, F2=0.5345558882235529, recall=0.6653726708074534, precision=0.299231843575419, specificity=0.6269516728624536, total=  26.4s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.1 ...............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.1, F2=0.5156526129765211, recall=0.6348096348096348, precision=0.2945205479452055, specificity=0.636177728202268, total=  26.1s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=0.1 ...............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=0.1, F2=0.5431131019036953, recall=0.6783216783216783, precision=0.30218068535825543, specificity=0.6252091466815394, total=  26.5s
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=1.0 ...............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=1.0, F2=0.5142204164550533, recall=0.6288819875776398, precision=0.2973568281938326, specificity=0.6442379182156134, total= 7.7min
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=1.0 ...............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=1.0, F2=0.49719887955182074, recall=0.6068376068376068, precision=0.2886178861788618, specificity=0.6421267893660532, total= 7.9min
# [CV] C=1.0, class_weight=balanced, degree=2, gamma=1.0 ...............
# [CV]  C=1.0, class_weight=balanced, degree=2, gamma=1.0, F2=0.5272045028142589, recall=0.655011655011655, precision=0.29610115911485774, specificity=0.6274400446179588, total= 7.7min
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.0001 ...........
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.0001, F2=0.5445083770519547, recall=0.9992236024844721, precision=0.19306930693069307, specificity=0.0001858736059479554, total=  30.8s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.0001 ...........
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=1.0, total=  30.7s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.0001 ...........
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.0001, F2=0.0, recall=0.0, precision=0.0, specificity=0.9998140918386317, total=  30.6s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.001 ............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.001, F2=0.42963514519731943, recall=0.44798136645962733, precision=0.3691618682021753, specificity=0.816728624535316, total=  30.3s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.001 ............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.001, F2=0.3289266603714196, recall=0.3247863247863248, precision=0.3466003316749585, specificity=0.8535043688417921, total=  30.6s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.001 ............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.001, F2=0.4018058690744921, recall=0.4149184149184149, precision=0.35671342685370744, specificity=0.8209704406023425, total=  31.3s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.01 .............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.01, F2=0.5381334671349725, recall=0.6661490683229814, precision=0.30425531914893617, specificity=0.6353159851301116, total=  24.1s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.01 .............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.01, F2=0.5180815593741985, recall=0.6278166278166278, precision=0.3049056603773585, specificity=0.6575571667596207, total=  23.8s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.01 .............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.01, F2=0.549263873159683, recall=0.6783216783216783, precision=0.31189710610932475, specificity=0.6419408812046848, total=  24.1s
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.1 ..............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.1, F2=0.519717777497795, recall=0.640527950310559, precision=0.296229802513465, specificity=0.6356877323420075, total= 1.1min
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.1 ..............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.1, F2=0.501712545985031, recall=0.6146076146076146, precision=0.28921389396709324, specificity=0.6385945343000557, total= 1.1min
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=0.1 ..............
# [CV]  C=10.0, class_weight=balanced, degree=2, gamma=0.1, F2=0.5328330206378986, recall=0.662004662004662, precision=0.2992623814541623, specificity=0.6291132180702733, total= 1.1min
# [CV] C=10.0, class_weight=balanced, degree=2, gamma=1.0 ..............

# %%
my_func.gs_score_summary(psvc_d2_gs)

# %%
scoring={'F2': f2_score,
         'recall':'recall',
         'precision':'precision'}

param_grid = {'C': np.concatenate((np.arange(0.000001, .00001, 0.000001),
                                   np.arange(0.00001, .0001, 0.00001),
                                   np.arange(0.0001, .001, 0.0001),
                                   np.arange(0.001, .01, 0.001),
                                   np.arange(0.01, .1, 0.01),
                                   np.arange(0.1, 1.1, 0.1)))}
              
lsvc_c_gs = GridSearchCV(estimator=LinearSVC(class_weight='balanced', loss='squared_hinge', dual=False, penalty='l1', tol=0.001),
                  param_grid = param_grid,
                  scoring=scoring,
                  cv=3,
                  refit=False,
                  n_jobs=4)

my_func.run_time(reset=True)
lsvc_c_gs.fit(X_train, y_train)
my_func.run_time()
# Out:
# Time: 1min 32s

# %%
my_func.plot_gs_param(lsvc_c_gs, set_xscale='log', ylim=(0, 0.8), figsize=(12,8))

# %%
lsvc_best = LinearSVC(class_weight='balanced', loss='squared_hinge', dual=False, penalty='l1', C=0.0001)

my_func.run_time(reset=True)
lsvc_best.fit(X_train, y_train)
my_func.run_time()
# Out:
# Time: 239ms

# %%
my_func.classifier_summary(y_train, lsvc_best.predict(X_train));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               59005               39309
# Actual Positive                7278               16182
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.541817
# Recall           0.689770
# Precision (pos)  0.291615
# Precision (neg)  0.890198
# Specificity      0.600169

# %%
my_func.classifier_summary(y_val, lsvc_best.predict(X_val));
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative               14835                9795
# Actual Positive                1823                3991
# --------------------
# Accuracy Scores:
#                     Score
# Rate
# F2               0.538713
# Recall           0.686447
# Precision (pos)  0.289497
# Precision (neg)  0.890563
# Specificity      0.602314
